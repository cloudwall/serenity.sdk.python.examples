# %% [markdown]
# # Demo: Serenity Scenario API
#
# Serenity lets you run stress tests on linear products -- portfolios of digital asset tokens -- in its current version. You can run scenarios that you create yourself, called custom scenarios, or you can use canned or predefined scenarios packaged with the Serenity platform. The API lets you manage your custom scenarios, execute scenario runs and retrieve run results programmatically, so if you wish to develop your own suite of regular scenarios to run against your portfolio you can easily script them.

# %%
# %%capture --no-stderr --no-display
# %load_ext autoreload
# %autoreload 2

# %%
from os import getenv
from serenity_sdk.widgets import ConnectWidget

# if you want to auto-connect, set this environment variable to your desired default
connect_widget = ConnectWidget(getenv('SERENITY_CONFIG_ID', None))
# Out:
# VBox(children=(HBox(children=(Text(value='', description='API Config:'),)), Button(description='Connect', icon…

# %%
import datetime
import re

from datetime import date
from uuid import UUID, uuid4

import pandas as pd

# create an alias to the api
api = connect_widget.get_api()

# %% [markdown]
# ## Getting started
#
# To run a scenario the first thing we need is a portfolio:

# %%
from serenity_types.portfolio.core import SimplePortfolio

asset_master = api.refdata().load_asset_master()

portfolio_raw = {
    'ADA': 1000000,
    'BTC': 100,
    'ETH': 1000,
    'XRP': 2000000,
    'ALGO': 1500000,
    'SOL': 10000,
    'DOT': 50000
}
portfolio = asset_master.create_portfolio(portfolio_raw, symbology='NATIVE')

# scenarios uses a special type, SimplePortfolio -- wrap it
simple_portfolio = SimplePortfolio(portfolio_id=uuid4(),
                                   portfolio_name='Test Portfolio',
                                   portfolio_manager='Test PM',
                                   base_currency_id=uuid4(),
                                   asset_positions=portfolio.to_asset_positions())

# %% [markdown]
# The starting point is to acquire a Scenarios API wrapper:

# %%
scenarios = api.scenarios()

# %% [markdown]
# ## Listing custom scenarios

# %%
custom_scenarios = scenarios.get_custom_scenarios().result
rows = []
for scenario in custom_scenarios:
    rows.append({'scenario_id': scenario.scenario_id, 'scenario_name': scenario.name})
pd.DataFrame(rows)
# Out:
#                               scenario_id  \
# 0    1c1fdcd1-052c-4273-a3cc-410917512b53
# 1    42413ee4-16ad-41a6-b409-637347660eec
# 2    7128cc34-ae85-44a0-b6d4-6b679ecc7995
# 3    0a56707d-ce96-49ab-9fcc-6c32a5adb8d1
# 4    137c4bb9-33af-4f6e-a347-71d75de82f22
# ..                                    ...
# 149  79b2fd41-53a9-42d9-ba09-d2f3d3033e40
# 150  12d5d59a-7d12-43a4-b85e-4bfe695a8644
# 151  6da9c98a-9ed9-438d-b7a7-a31d780bb890
# 152  520b088f-5c19-4e13-9e71-5d44f5579f58
# 153  f1ea53a7-2ba5-436e-bcf2-0098a23274a9
#
#                                          scenario_name
# 0         Custom Scenario - 2022-10-21 09:10:38.985755
# 1    Updated Scenario Name - 2022-10-21 09:10:39.53...
# 2         Custom Scenario - 2022-10-21 09:10:40.317501
# 3    Updated Scenario Name - 2022-10-21 09:10:41.85...
# 4    Updated Scenario Name - 2022-10-21 09:10:42.63...
# ..                                                 ...
# 149       Custom Scenario - 2022-12-15 06:34:58.213353
# 150       Custom Scenario - 2022-12-15 06:34:58.726150
# 151                                     FTX Bankruptcy
# 152                                        ZJ Scenario
# 153                                        ZJ Scenario
#
# [154 rows x 2 columns]

# %% [markdown]
# ## Listing predefined scenarios

# %%
predefined_scenarios = scenarios.get_predefined_scenarios().result
scenario_by_name = {}
rows = []
for scenario in predefined_scenarios:
    name_elements = re.split(':\s', scenario.name)
    model_config_id = UUID(name_elements[0])
    scenario_name = name_elements[1]
    rows.append({'scenario_id': scenario.scenario_id, 'model_config_id': model_config_id, 'scenario_name': scenario_name})
    scenario_by_name[scenario_name] = {'scenario': scenario, 'model_config_id': model_config_id}
pd.DataFrame(rows)
# Out:
#                              scenario_id  \
# 0   d983f302-a3d4-4d35-a713-768ac8a9ff68
# 1   4e98301b-b901-4c2e-adf9-f8d5f38310c4
# 2   5ebf5855-38c2-4be6-9301-13fe1c30d6d7
# 3   dbf00795-f5b6-48ed-9093-fac7f76ad7af
# 4   e7c69342-ae7d-4e31-a7aa-340e67db1cbd
# 5   8ad3c606-8229-4af5-b898-ba57c4603486
# 6   6f33ec34-c363-4f26-80a9-e3bd26adc757
# 7   619db52d-074b-4c48-ae17-d3995f6804fc
# 8   b4b7c5a9-ffd1-4b63-a9fa-40936f8f5670
# 9   ffcf07dd-0919-4734-b9e0-fc5902771c28
# 10  e84add5e-09f9-43fb-a6de-b343e9fddf3c
# 11  c6220bc9-1574-42c9-aa9b-712cb91dd655
# 12  c52a9717-35d9-432c-b0eb-6899e7acd968
# 13  cf56cb4e-58ee-4a25-a267-c472a6b4b543
# 14  b5a1b351-4b54-41a6-ac07-ca65c5010999
# 15  0bada8c6-6b9b-11ed-a1eb-0242ac120002
# 16  d983f302-a3d4-4d35-a713-768ac8a9ff68
# 17  4e98301b-b901-4c2e-adf9-f8d5f38310c4
# 18  5ebf5855-38c2-4be6-9301-13fe1c30d6d7
# 19  dbf00795-f5b6-48ed-9093-fac7f76ad7af
# 20  e7c69342-ae7d-4e31-a7aa-340e67db1cbd
# 21  8ad3c606-8229-4af5-b898-ba57c4603486
# 22  6f33ec34-c363-4f26-80a9-e3bd26adc757
# 23  619db52d-074b-4c48-ae17-d3995f6804fc
# 24  b4b7c5a9-ffd1-4b63-a9fa-40936f8f5670
# 25  ffcf07dd-0919-4734-b9e0-fc5902771c28
# 26  e84add5e-09f9-43fb-a6de-b343e9fddf3c
# 27  c6220bc9-1574-42c9-aa9b-712cb91dd655
# 28  c52a9717-35d9-432c-b0eb-6899e7acd968
# 29  cf56cb4e-58ee-4a25-a267-c472a6b4b543
# 30  b5a1b351-4b54-41a6-ac07-ca65c5010999
# 31  0bada8c6-6b9b-11ed-a1eb-0242ac120002
# 32  d983f302-a3d4-4d35-a713-768ac8a9ff68
# 33  4e98301b-b901-4c2e-adf9-f8d5f38310c4
# 34  5ebf5855-38c2-4be6-9301-13fe1c30d6d7
# 35  dbf00795-f5b6-48ed-9093-fac7f76ad7af
# 36  e7c69342-ae7d-4e31-a7aa-340e67db1cbd
# 37  8ad3c606-8229-4af5-b898-ba57c4603486
# 38  6f33ec34-c363-4f26-80a9-e3bd26adc757
# 39  619db52d-074b-4c48-ae17-d3995f6804fc
# 40  b4b7c5a9-ffd1-4b63-a9fa-40936f8f5670
# 41  ffcf07dd-0919-4734-b9e0-fc5902771c28
# 42  e84add5e-09f9-43fb-a6de-b343e9fddf3c
# 43  c6220bc9-1574-42c9-aa9b-712cb91dd655
# 44  c52a9717-35d9-432c-b0eb-6899e7acd968
# 45  cf56cb4e-58ee-4a25-a267-c472a6b4b543
# 46  b5a1b351-4b54-41a6-ac07-ca65c5010999
# 47  0bada8c6-6b9b-11ed-a1eb-0242ac120002
#
#                          model_config_id  \
# 0   ce3a7d83-4133-404a-99ac-5f3777f8dc2d
# 1   ce3a7d83-4133-404a-99ac-5f3777f8dc2d
# 2   ce3a7d83-4133-404a-99ac-5f3777f8dc2d
# 3   ce3a7d83-4133-404a-99ac-5f3777f8dc2d
# 4   ce3a7d83-4133-404a-99ac-5f3777f8dc2d
# 5   ce3a7d83-4133-404a-99ac-5f3777f8dc2d
# 6   ce3a7d83-4133-404a-99ac-5f3777f8dc2d
# 7   ce3a7d83-4133-404a-99ac-5f3777f8dc2d
# 8   ce3a7d83-4133-404a-99ac-5f3777f8dc2d
# 9   ce3a7d83-4133-404a-99ac-5f3777f8dc2d
# 10  ce3a7d83-4133-404a-99ac-5f3777f8dc2d
# 11  ce3a7d83-4133-404a-99ac-5f3777f8dc2d
# 12  ce3a7d83-4133-404a-99ac-5f3777f8dc2d
# 13  ce3a7d83-4133-404a-99ac-5f3777f8dc2d
# 14  ce3a7d83-4133-404a-99ac-5f3777f8dc2d
# 15  ce3a7d83-4133-404a-99ac-5f3777f8dc2d
# 16  2c7bdb82-6d01-47fa-a832-d0dba7382692
# 17  2c7bdb82-6d01-47fa-a832-d0dba7382692
# 18  2c7bdb82-6d01-47fa-a832-d0dba7382692
# 19  2c7bdb82-6d01-47fa-a832-d0dba7382692
# 20  2c7bdb82-6d01-47fa-a832-d0dba7382692
# 21  2c7bdb82-6d01-47fa-a832-d0dba7382692
# 22  2c7bdb82-6d01-47fa-a832-d0dba7382692
# 23  2c7bdb82-6d01-47fa-a832-d0dba7382692
# 24  2c7bdb82-6d01-47fa-a832-d0dba7382692
# 25  2c7bdb82-6d01-47fa-a832-d0dba7382692
# 26  2c7bdb82-6d01-47fa-a832-d0dba7382692
# 27  2c7bdb82-6d01-47fa-a832-d0dba7382692
# 28  2c7bdb82-6d01-47fa-a832-d0dba7382692
# 29  2c7bdb82-6d01-47fa-a832-d0dba7382692
# 30  2c7bdb82-6d01-47fa-a832-d0dba7382692
# 31  2c7bdb82-6d01-47fa-a832-d0dba7382692
# 32  c23175a5-d76f-4f32-963b-c0d0f3535caf
# 33  c23175a5-d76f-4f32-963b-c0d0f3535caf
# 34  c23175a5-d76f-4f32-963b-c0d0f3535caf
# 35  c23175a5-d76f-4f32-963b-c0d0f3535caf
# 36  c23175a5-d76f-4f32-963b-c0d0f3535caf
# 37  c23175a5-d76f-4f32-963b-c0d0f3535caf
# 38  c23175a5-d76f-4f32-963b-c0d0f3535caf
# 39  c23175a5-d76f-4f32-963b-c0d0f3535caf
# 40  c23175a5-d76f-4f32-963b-c0d0f3535caf
# 41  c23175a5-d76f-4f32-963b-c0d0f3535caf
# 42  c23175a5-d76f-4f32-963b-c0d0f3535caf
# 43  c23175a5-d76f-4f32-963b-c0d0f3535caf
# 44  c23175a5-d76f-4f32-963b-c0d0f3535caf
# 45  c23175a5-d76f-4f32-963b-c0d0f3535caf
# 46  c23175a5-d76f-4f32-963b-c0d0f3535caf
# 47  c23175a5-d76f-4f32-963b-c0d0f3535caf
#
#                                         scenario_name
# 0                           Facebook Renaming to Meta
# 1                 LUNA Crash and Crypto Credit Crunch
# 2                                      3AC Insolvency
# 3                                Wormhole Bridge Hack
# 4                         Ethereum Merge Announcement
# 5                                    2017 Bull Market
# 6              2018 Bear Market - First Crypto Winter
# 7                                    2019 Bull Market
# 8                                    2020 COVID Crash
# 9   2019 COVID Downturns and Sideways Market - Sec...
# 10                                2020 COVID Recovery
# 11                                   2020 DeFi Summer
# 12                            2020 Crypto Exhuberance
# 13        2021 March 2021 Crash - Third Crypto Winter
# 14                              2021 China Crypto Ban
# 15                                2022 FTX Bankruptcy
# 16                          Facebook Renaming to Meta
# 17                LUNA Crash and Crypto Credit Crunch
# 18                                     3AC Insolvency
# 19                               Wormhole Bridge Hack
# 20                        Ethereum Merge Announcement
# 21                                   2017 Bull Market
# 22             2018 Bear Market - First Crypto Winter
# 23                                   2019 Bull Market
# 24                                   2020 COVID Crash
# 25  2019 COVID Downturns and Sideways Market - Sec...
# 26                                2020 COVID Recovery
# 27                                   2020 DeFi Summer
# 28                            2020 Crypto Exhuberance
# 29        2021 March 2021 Crash - Third Crypto Winter
# 30                              2021 China Crypto Ban
# 31                                2022 FTX Bankruptcy
# 32                          Facebook Renaming to Meta
# 33                LUNA Crash and Crypto Credit Crunch
# 34                                     3AC Insolvency
# 35                               Wormhole Bridge Hack
# 36                        Ethereum Merge Announcement
# 37                                   2017 Bull Market
# 38             2018 Bear Market - First Crypto Winter
# 39                                   2019 Bull Market
# 40                                   2020 COVID Crash
# 41  2019 COVID Downturns and Sideways Market - Sec...
# 42                                2020 COVID Recovery
# 43                                   2020 DeFi Summer
# 44                            2020 Crypto Exhuberance
# 45        2021 March 2021 Crash - Third Crypto Winter
# 46                              2021 China Crypto Ban
# 47                                2022 FTX Bankruptcy

# %% [markdown]
# ## Managing custom scenarios

# %%
from serenity_types.risk.scenarios import ScenarioCloneRequest, ScenarioDefinition, ScenarioSource

# create a custom scenario, letting the server allocated ID and version
custom = ScenarioDefinition(scenario_id=None, scenario_version=None,
                            source=ScenarioSource.CUSTOM,
                            name='Demo Custom Scenario',
                            shocks=[], last_updated_by='SDK notebook')
custom = scenarios.create_custom_scenario(custom).result

# update it
custom.name='Demo Custom Scenario MODIFIED'
custom = scenarios.update_custom_scenario(custom).result

# rollback
custom = scenarios.rollback_custom_scenario(custom.scenario_id, version=custom.scenario_version).result

# clone it
clone_request = ScenarioCloneRequest(scenario_id=custom.scenario_id, scenario_name=f'{custom.name} - CLONED')
custom_clone = scenarios.clone_scenario(clone_request).result

# delete the scenario and its clone
assert scenarios.delete_custom_scenario(custom.scenario_id).result.deleted
assert scenarios.delete_custom_scenario(custom_clone.scenario_id).result.deleted

# %% [markdown]
# ## Running a predefined scenario

# %%
from serenity_sdk.client.raw import SerenityError
from serenity_types.risk.scenarios import ScenarioRequest
from serenity_types.pricing.core import PricingContext

scenario_info = scenario_by_name['3AC Insolvency']
predefined_scenario = scenario_info['scenario']
model_config_id = scenario_info['model_config_id']
start_date = date(2022, 12, 26)
pricing_context = PricingContext(as_of_date=start_date)
request = ScenarioRequest(scenario_id=None, scenario=predefined_scenario, portfolio=simple_portfolio,
                          pricing_context=pricing_context, model_config_id=model_config_id,
                          start_date=start_date, end_date=start_date, schema_version=1)

scenarios.run_scenario(request)
# Out:
# Response(request_id=UUID('46a6c6af-f9a5-4ff6-9e46-a7b5a8cbb742'), as_of_date=datetime.date(2022, 12, 26), warnings=[], result=ScenarioResult(portfolio_pnl=PnL(base_pnl=76233.18064846103, total_shock_pnl=203607.46473071218, pnl_by_shock=[ShockPnL(shock_id=UUID('1bcca942-b993-4358-8119-6f10c7505801'), shock_pnl=-4042.9920372105225), ShockPnL(shock_id=UUID('1ff71aab-4d9a-43da-b7c6-09d2ac8265a2'), shock_pnl=1537.7288060782555), ShockPnL(shock_id=UUID('3d2e4587-1599-43a5-9d66-a66ba45fc843'), shock_pnl=11819.44847895085), ShockPnL(shock_id=UUID('52b3433f-62b7-43c7-9ef6-1e7698be902f'), shock_pnl=-29338.132872336202), ShockPnL(shock_id=UUID('56f0096b-d011-476d-b01a-38cd528d3d97'), shock_pnl=16134.73895441492), ShockPnL(shock_id=UUID('770dd6f9-72fb-4d9b-9f29-21b3e3bf6081'), shock_pnl=-29665.089355515287), ShockPnL(shock_id=UUID('8b9dbfda-a714-4e46-af95-3517c17569ff'), shock_pnl=12758.799090638639), ShockPnL(shock_id=UUID('96e58bde-6088-4c0b-ba88-30a8a2bd7537'), shock_pnl=25276.84574416292), ShockPnL(shock_id=UUID('c24e6384-acdf-4b77-83ce-0bab7eef5813'), shock_pnl=-15634.418595647532), ShockPnL(shock_id=UUID('c36f8ad6-c40f-4379-8320-0799b4ee20c1'), shock_pnl=179949.0666772317), ShockPnL(shock_id=UUID('d591fe1a-8e33-4a83-82b5-c99aeb740332'), shock_pnl=21179.637478896657), ShockPnL(shock_id=UUID('e370e498-21a3-42f0-94e2-9b94d1878549'), shock_pnl=13631.832361047782)]), asset_pnl=[AssetPnL(asset_id=UUID('192f10b4-f0a7-4e7a-a66c-204d90acd1e2'), sector_levels=['Currency', 'BaaS', 'Payments'], asset_pnl=PnL(base_pnl=45236.67260825437, total_shock_pnl=65754.53720520898, pnl_by_shock=[ShockPnL(shock_id=UUID('1bcca942-b993-4358-8119-6f10c7505801'), shock_pnl=-1143.478183727499), ShockPnL(shock_id=UUID('1ff71aab-4d9a-43da-b7c6-09d2ac8265a2'), shock_pnl=1537.1107678787803), ShockPnL(shock_id=UUID('52b3433f-62b7-43c7-9ef6-1e7698be902f'), shock_pnl=9556.936199689542), ShockPnL(shock_id=UUID('8b9dbfda-a714-4e46-af95-3517c17569ff'), shock_pnl=2525.921631928805), ShockPnL(shock_id=UUID('96e58bde-6088-4c0b-ba88-30a8a2bd7537'), shock_pnl=25276.84574416292), ShockPnL(shock_id=UUID('c36f8ad6-c40f-4379-8320-0799b4ee20c1'), shock_pnl=28001.201045276426)])), AssetPnL(asset_id=UUID('78e2e8e2-419d-4515-9b6a-3d5ff1448e89'), sector_levels=['Currency', 'Transparent', 'Transparent DeFi Currency'], asset_pnl=PnL(base_pnl=4372.610174912188, total_shock_pnl=7673.594581521833, pnl_by_shock=[ShockPnL(shock_id=UUID('1bcca942-b993-4358-8119-6f10c7505801'), shock_pnl=-2815.9316973829236), ShockPnL(shock_id=UUID('1ff71aab-4d9a-43da-b7c6-09d2ac8265a2'), shock_pnl=-1621.6457116759427), ShockPnL(shock_id=UUID('52b3433f-62b7-43c7-9ef6-1e7698be902f'), shock_pnl=-19506.793475538227), ShockPnL(shock_id=UUID('770dd6f9-72fb-4d9b-9f29-21b3e3bf6081'), shock_pnl=-29665.089355515287), ShockPnL(shock_id=UUID('8b9dbfda-a714-4e46-af95-3517c17569ff'), shock_pnl=4765.216626405337), ShockPnL(shock_id=UUID('c36f8ad6-c40f-4379-8320-0799b4ee20c1'), shock_pnl=56517.83819522888)])), AssetPnL(asset_id=UUID('9111a3cf-51de-4c9b-ad18-f140353374cb'), sector_levels=['Smart Contract Platform', 'Layer 1', 'Layer 1'], asset_pnl=PnL(base_pnl=-1281.1833886247114, total_shock_pnl=20658.648661415424, pnl_by_shock=[ShockPnL(shock_id=UUID('1bcca942-b993-4358-8119-6f10c7505801'), shock_pnl=-515.7246873232662), ShockPnL(shock_id=UUID('1ff71aab-4d9a-43da-b7c6-09d2ac8265a2'), shock_pnl=-0.8864515667528259), ShockPnL(shock_id=UUID('3d2e4587-1599-43a5-9d66-a66ba45fc843'), shock_pnl=11819.44847895085), ShockPnL(shock_id=UUID('52b3433f-62b7-43c7-9ef6-1e7698be902f'), shock_pnl=3492.3696141738687), ShockPnL(shock_id=UUID('8b9dbfda-a714-4e46-af95-3517c17569ff'), shock_pnl=-373.89652014874025), ShockPnL(shock_id=UUID('c36f8ad6-c40f-4379-8320-0799b4ee20c1'), shock_pnl=6237.338227329462)])), AssetPnL(asset_id=UUID('95b89dfd-c5f6-41d6-83c6-a9d97e0ac361'), sector_levels=['Smart Contract Platform', 'Layer 1', 'Layer 1'], asset_pnl=PnL(base_pnl=5982.336613373036, total_shock_pnl=26829.482149602332, pnl_by_shock=[ShockPnL(shock_id= ...
